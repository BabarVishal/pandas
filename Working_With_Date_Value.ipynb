# %%
import pandas as pd;

# %%
data = {
    'name':['vishal', 'om', 'Shubz'],
    'age' : [22,12,33]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#      name  age
# 0  vishal   22
# 1      om   12
# 2   Shubz   33

# %%
df['DOJ'] = ['2002-12-22', '2003-2-23', '2023-11-11']

# %%
df
# Out:
#      name  age         DOJ
# 0  vishal   22  2002-12-22
# 1      om   12   2003-2-23
# 2   Shubz   33  2023-11-11

# %%
df['DOJ'].dtype
# Out:
# dtype('O')

# %%
df['DOJ'] = pd.to_datetime(df['DOJ'])

# %%
df['DOJ'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df
# Out:
#      name  age        DOJ
# 0  vishal   22 2002-12-22
# 1      om   12 2003-02-23
# 2   Shubz   33 2023-11-11

# %%
data = df.drop('DOJ', axis=1)
data
# Out:
#      name  age
# 0  vishal   22
# 1      om   12
# 2   Shubz   33

# %%
data
# Out:
#      name  age
# 0  vishal   22
# 1      om   12
# 2   Shubz   33

# %%
data['Doj'] = ['01-12-2002', '23-04-2004', '11-11-2005']

# %%
data
# Out:
#      name  age         Doj
# 0  vishal   22  01-12-2002
# 1      om   12  23-04-2004
# 2   Shubz   33  11-11-2005

# %%
data['Doj'].dtype
# Out:
# dtype('O')

# %%
data['Doj'] = pd.to_datetime(data['Doj'], format = '%d-%m-%Y')

# %%
data
# Out:
#      name  age        Doj
# 0  vishal   22 2002-12-01
# 1      om   12 2004-04-23
# 2   Shubz   33 2005-11-11

# %%
data['Doj'].dtype
# Out:
# dtype('<M8[ns]')

# %%
data
# Out:
#      name  age        Doj
# 0  vishal   22 2002-12-01
# 1      om   12 2004-04-23
# 2   Shubz   33 2005-11-11

# %%
data['Doj'].dt.year
data['Doj'].dt.month
data['Doj'].dt.day
data['Doj'].dt.day_name()
# Out:
# 0    Sunday
# 1    Friday
# 2    Friday
# Name: Doj, dtype: object
