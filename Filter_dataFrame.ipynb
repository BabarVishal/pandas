# %%
import pandas as pd;

# %%
data = pd.DataFrame({
    'name':['vishal', 'om', 'shubz', 'mayur'], 
    'age':[22,33,44,55], 
    'department':['cs', 'IT', 'Chemical', 'Ai-Ml'], 
    'salary':[34222,55533,55222,55111]
})
data
# Out:
#      name  age department  salary
# 0  vishal   22         cs   34222
# 1      om   33         IT   55533
# 2   shubz   44   Chemical   55222
# 3   mayur   55      Ai-Ml   55111

# %%
data['age'] >= 44
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: age, dtype: bool

# %%
data[(data['name'] == 'vishal') & (data['age'] >= 22)]
# Out:
#      name  age department  salary
# 0  vishal   22         cs   34222

# %%
data.where(data['age'] >= 44)
# Out:
#     name   age department   salary
# 0    NaN   NaN        NaN      NaN
# 1    NaN   NaN        NaN      NaN
# 2  shubz  44.0   Chemical  55222.0
# 3  mayur  55.0      Ai-Ml  55111.0
