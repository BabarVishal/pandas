# %%
import pandas as pd;

# %%
data = pd.DataFrame({
    'name':['vishal', 'om', 'shubz'],
    'age':[21,22,32]
})
data
# Out:
#      name  age
# 0  vishal   21
# 1      om   22
# 2   shubz   32

# %%
data.head()
# Out:
#      name  age
# 0  vishal   21
# 1      om   22
# 2   shubz   32

# %%
data.tail()
# Out:
#      name  age
# 0  vishal   21
# 1      om   22
# 2   shubz   32

# %%
data.size
# Out:
# 6

# %%
data.shape
# Out:
# (3, 2)

# %%
data.info
# Out:
# <bound method DataFrame.info of      name  age
# 0  vishal   21
# 1      om   22
# 2   shubz   32>

# %%
data.describe()
# Out:
#              age
# count   3.000000
# mean   25.000000
# std     6.082763
# min    21.000000
# 25%    21.500000
# 50%    22.000000
# 75%    27.000000
# max    32.000000

# %%
data.rename(columns={'name':'Full_name'})
# Out:
#   Full_name  age
# 0    vishal   21
# 1        om   22
# 2     shubz   32

# %%
data.to_csv('data1', index=False)

# %%
load = pd.read_csv('data1')

# %%
load
# Out:
#      name  age
# 0  vishal   21
# 1      om   22
# 2   shubz   32

# %%
load['depatment'] = ['cs', 'IT', 'Al']

# %%
load
# Out:
#      name  age depatment
# 0  vishal   21        cs
# 1      om   22        IT
# 2   shubz   32        Al

# %%
load.drop('depatment', axis=1)
# Out:
#      name  age
# 0  vishal   21
# 1      om   22
# 2   shubz   32

# %%
load
# Out:
#      name  age depatment
# 0  vishal   21        cs
# 1      om   22        IT
# 2   shubz   32        Al

# %%
load.loc[len(load)] =['mayur', 22, 'cs']

# %%
load
# Out:
#      name  age depatment
# 0  vishal   21        cs
# 1      om   22        IT
# 2   shubz   32        Al
# 3   mayur   22        cs

# %%
load.drop(load[load.name == 'vishal'].index)
# Out:
#     name  age depatment
# 1     om   22        IT
# 2  shubz   32        Al
# 3  mayur   22        cs

# %%
load.loc[0, 'age'] = 33

# %%
load
# Out:
#      name  age depatment
# 0  vishal   33        cs
# 1      om   22        IT
# 2   shubz   32        Al
# 3   mayur   22        cs

# %%
load[['name']]
# Out:
#      name
# 0  vishal
# 1      om
# 2   shubz
# 3   mayur

# %%
load.loc[load.name == 'vishal']
# Out:
#      name  age depatment
# 0  vishal   33        cs

# %%
load
# Out:
#      name  age depatment
# 0  vishal   33        cs
# 1      om   22        IT
# 2   shubz   32        Al
# 3   mayur   22        cs

# %%
load['name'] == 'vishal'
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# Name: name, dtype: bool

# %%
load[load.name == 'vishal']
# Out:
#      name  age depatment
# 0  vishal   33        cs

# %%
load.where(load.name == 'vishal')
# Out:
#      name   age depatment
# 0  vishal  33.0        cs
# 1     NaN   NaN       NaN
# 2     NaN   NaN       NaN
# 3     NaN   NaN       NaN
