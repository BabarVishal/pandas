# %%
import pandas as pd;

# %%
data = pd.DataFrame({
    'name': ['vishal', 'babar', 'om', 'mayur'], 
    'age':[23,33,44,22], 
    'department':['Cs', 'Chemical', 'IT', 'AI-ML']
})
data
# Out:
#      name  age department
# 0  vishal   23         Cs
# 1   babar   33   Chemical
# 2      om   44         IT
# 3   mayur   22      AI-ML

# %%
data['date'] = ['2003-12-22', '2003-12-22', '2003-12-22', '2003-12-22' ]

# %%
data
# Out:
#      name  age department        date
# 0  vishal   23         Cs  2003-12-22
# 1   babar   33   Chemical  2003-12-22
# 2      om   44         IT  2003-12-22
# 3   mayur   22      AI-ML  2003-12-22

# %%
data['date'].dtype
# Out:
# dtype('O')

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data['date'].dtype
# Out:
# dtype('<M8[ns]')
