# %%
import pandas as pd;

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
data = {
    'name':['vishal', 'om', 'shubz'],
    'age':[22,12,22],
    'salary':[50000, 40000, 50000],
    'Department':['Computer', 'Chemical', 'cs']
}

df = pd.DataFrame(data)
print(df)
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer
# 1      om   12   40000   Chemical
# 2   shubz   22   50000         cs

# %%
df.loc[df.name == 'vishal']  #Selecting rows
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer

# %%
df.loc[(df.name == 'om') & (df.age >= 21)]
# Out:
# Empty DataFrame
# Columns: [name, age, salary, Department]
# Index: []

# %%
df[['name','age']] # Selecting Coloumn
# Out:
#      name  age
# 0  vishal   22
# 1      om   12
# 2   shubz   22

# %%
df['age'] >= 21
# Out:
# 0     True
# 1    False
# 2     True
# Name: age, dtype: bool

# %%
df[(df['age'] >= 21) & (df['salary'] >= 50000)]
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer
# 2   shubz   22   50000         cs

# %%
df
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer
# 1      om   12   40000   Chemical
# 2   shubz   22   50000         cs

# %%
df[['Department', 'name']]
# Out:
#   Department    name
# 0   Computer  vishal
# 1   Chemical      om
# 2         cs   shubz

# %%
df
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer
# 1      om   12   40000   Chemical
# 2   shubz   22   50000         cs

# %%
df.loc[df.name == 'vishal']
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer

# %%
df.loc[df.name == 'om']
# Out:
#   name  age  salary Department
# 1   om   12   40000   Chemical

# %%
df
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer
# 1      om   12   40000   Chemical
# 2   shubz   22   50000         cs

# %%
df[['name', 'age']]
# Out:
#      name  age
# 0  vishal   22
# 1      om   12
# 2   shubz   22

# %%
df
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer
# 1      om   12   40000   Chemical
# 2   shubz   22   50000         cs

# %%
df.loc[df.name == 'vishal']
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer

# %%
df
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer
# 1      om   12   40000   Chemical
# 2   shubz   22   50000         cs

# %%
df['age'] >= 21
# Out:
# 0     True
# 1    False
# 2     True
# Name: age, dtype: bool

# %%
df[(df['age'] >= 21) & (df['salary'] >= 50000)]
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer
# 2   shubz   22   50000         cs

# %%
df
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer
# 1      om   12   40000   Chemical
# 2   shubz   22   50000         cs

# %%
df['Team'] = ['Hr', 'It', 'Ceo']

# %%
df
# Out:
#      name  age  salary Department Team
# 0  vishal   22   50000   Computer   Hr
# 1      om   12   40000   Chemical   It
# 2   shubz   22   50000         cs  Ceo

# %%
df.drop('Team', axis=1)
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer
# 1      om   12   40000   Chemical
# 2   shubz   22   50000         cs

# %%
df
# Out:
#      name  age  salary Department Team
# 0  vishal   22   50000   Computer   Hr
# 1      om   12   40000   Chemical   It
# 2   shubz   22   50000         cs  Ceo

# %%
Delete_Column = df.drop('Team', axis=1)

# %%
print(Delete_Column)
# Out:
#      name  age  salary Department
# 0  vishal   22   50000   Computer
# 1      om   12   40000   Chemical
# 2   shubz   22   50000         cs

# %%
print(df)
# Out:
#      name  age  salary Department Team
# 0  vishal   22   50000   Computer   Hr
# 1      om   12   40000   Chemical   It
# 2   shubz   22   50000         cs  Ceo

# %%
add_Column = df['Year'] = [1,2,3]

# %%
add_Column
# Out:
# [1, 2, 3]

# %%
df
# Out:
#      name  age  salary Department Team  Year
# 0  vishal   22   50000   Computer   Hr     1
# 1      om   12   40000   Chemical   It     2
# 2   shubz   22   50000         cs  Ceo     3

# %%
remove = df.drop('Year', axis=1)

# %%
remove
# Out:
#      name  age  salary Department Team
# 0  vishal   22   50000   Computer   Hr
# 1      om   12   40000   Chemical   It
# 2   shubz   22   50000         cs  Ceo
