# %%
import pandas as pd;

# %%
data = {
 'name':['vishal', 'om', 'shubz', 'omkar'],
 'age':[22,33,44,55], 
 'department':['Computer', 'It', 'Cs', 'AI-ML'], 
'salary':[33333,44444,55555,66666]
}

data = pd.DataFrame(data)
data
# Out:
#      name  age department  salary
# 0  vishal   22   Computer   33333
# 1      om   33         It   44444
# 2   shubz   44         Cs   55555
# 3   omkar   55      AI-ML   66666

# %%
data.isnull()
# Out:
#     name    age  department  salary
# 0  False  False       False   False
# 1  False  False       False   False
# 2  False  False       False   False
# 3  False  False       False   False

# %%
import numpy as np;
data.loc[data.name == 'vishal', 'Salary'] = np.nan

# %%
data
# Out:
#      name  age department  salary  Salary
# 0  vishal   22   Computer   33333     NaN
# 1      om   33         It   44444     NaN
# 2   shubz   44         Cs   55555     NaN
# 3   omkar   55      AI-ML   66666     NaN

# %%
data.isnull()
# Out:
#     name    age  department  salary  Salary
# 0  False  False       False   False    True
# 1  False  False       False   False    True
# 2  False  False       False   False    True
# 3  False  False       False   False    True

# %%
data.isnull().sum()
# Out:
# name          0
# age           0
# department    0
# salary        0
# Salary        4
# dtype: int64

# %%
data.fillna(0)
# Out:
#      name  age department  salary  Salary
# 0  vishal   22   Computer   33333     0.0
# 1      om   33         It   44444     0.0
# 2   shubz   44         Cs   55555     0.0
# 3   omkar   55      AI-ML   66666     0.0
