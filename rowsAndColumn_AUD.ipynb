# %%
import pandas as pd;

# %%
data = {
    'name':['vishal', 'om', 'shubz'],
    'age':[22,33,44], 
    'department':['IT', 'CS', 'Ai-ML']
}

df = pd.DataFrame(data)

# %%
df
# Out:
#      name  age department
# 0  vishal   22         IT
# 1      om   33         CS
# 2   shubz   44      Ai-ML

# %%
df['salary'] = [23455,22222,55533]

# %%
df
# Out:
#      name  age department  salary
# 0  vishal   22         IT   23455
# 1      om   33         CS   22222
# 2   shubz   44      Ai-ML   55533

# %%
df.drop('salary', axis=1)
# Out:
#      name  age department
# 0  vishal   22         IT
# 1      om   33         CS
# 2   shubz   44      Ai-ML

# %%
df.loc[len(df)] = ['mayur', 22, 'IT', 234433]

# %%
df
# Out:
#      name  age department  salary
# 0  vishal   22         IT   23455
# 1      om   33         CS   22222
# 2   shubz   44      Ai-ML   55533
# 3   mayur   22         IT  234433

# %%
df.drop(df[df.name == 'mayur'].index)
# Out:
#      name  age department  salary
# 0  vishal   22         IT   23455
# 1      om   33         CS   22222
# 2   shubz   44      Ai-ML   55533

# %%
df
# Out:
#      name  age department  salary
# 0  vishal   22         IT   23455
# 1      om   33         CS   22222
# 2   shubz   44      Ai-ML   55533
# 3   mayur   22         IT  234433

# %%
df['Roomnumber'] = [2,3,4,5]

# %%
df
# Out:
#      name  age department  salary  Roomnumber
# 0  vishal   22         IT   23455           2
# 1      om   33         CS   22222           3
# 2   shubz   44      Ai-ML   55533           4
# 3   mayur   22         IT  234433           5

# %%
df.drop('Roomnumber', axis=1)
# Out:
#      name  age department  salary
# 0  vishal   22         IT   23455
# 1      om   33         CS   22222
# 2   shubz   44      Ai-ML   55533
# 3   mayur   22         IT  234433

# %%
df
# Out:
#      name  age department  salary  Roomnumber
# 0  vishal   22         IT   23455           2
# 1      om   33         CS   22222           3
# 2   shubz   44      Ai-ML   55533           4
# 3   mayur   22         IT  234433           5

# %%
df.loc[len(df)] = ['addi', 33, 'cs', 344322, 4]

# %%
df
# Out:
#      name  age department  salary  Roomnumber
# 0  vishal   22         IT   23455           2
# 1      om   33         CS   22222           3
# 2   shubz   44      Ai-ML   55533           4
# 3   mayur   22         IT  234433           5
# 4    addi   33         cs  344322           4

# %%
df.drop(df[df.name == 'addi'].index)
# Out:
#      name  age department  salary  Roomnumber
# 0  vishal   22         IT   23455           2
# 1      om   33         CS   22222           3
# 2   shubz   44      Ai-ML   55533           4
# 3   mayur   22         IT  234433           5

# %%
df.loc[0, 'salary'] == 50000
# Out:
# np.False_

# %%
df
# Out:
#      name  age department  salary  Roomnumber
# 0  vishal   22         IT   23455           2
# 1      om   33         CS   22222           3
# 2   shubz   44      Ai-ML   55533           4
# 3   mayur   22         IT  234433           5
# 4    addi   33         cs  344322           4
