# %%
import pandas as pd;

# %%
data = pd.DataFrame([1,2,3,4], columns=['serial'])
data
# Out:
#    serial
# 0       1
# 1       2
# 2       3
# 3       4

# %%
data2 = pd.DataFrame({
    'name':['vishal', 'om', 'shubz'], 
    'age':[22,33,44], 
    'department':['computer', 'chemical', 'IT'], 
    'joing_Date':['2002-01-30', '2023-12-23', '2024-12-2'] 
})
data2
# Out:
#      name  age department  joing_Date
# 0  vishal   22   computer  2002-01-30
# 1      om   33   chemical  2023-12-23
# 2   shubz   44         IT   2024-12-2

# %%
data2.head()
# Out:
#      name  age department  joing_Date
# 0  vishal   22   computer  2002-01-30
# 1      om   33   chemical  2023-12-23
# 2   shubz   44         IT   2024-12-2

# %%
data2.tail()
# Out:
#      name  age department  joing_Date
# 0  vishal   22   computer  2002-01-30
# 1      om   33   chemical  2023-12-23
# 2   shubz   44         IT   2024-12-2

# %%
data2.shape
# Out:
# (3, 4)

# %%
data2.size
# Out:
# 12

# %%
data2.describe()
# Out:
#         age
# count   3.0
# mean   33.0
# std    11.0
# min    22.0
# 25%    27.5
# 50%    33.0
# 75%    38.5
# max    44.0

# %%
data2.info
# Out:
# <bound method DataFrame.info of      name  age department  joing_Date
# 0  vishal   22   computer  2002-01-30
# 1      om   33   chemical  2023-12-23
# 2   shubz   44         IT   2024-12-2>

# %%
data2 = data2.rename(columns={'name':'Full_name'})

# %%
data2
# Out:
#   Full_name  age department  joing_Date
# 0    vishal   22   computer  2002-01-30
# 1        om   33   chemical  2023-12-23
# 2     shubz   44         IT   2024-12-2

# %%
data2
# Out:
#   Full_name  age department  joing_Date
# 0    vishal   22   computer  2002-01-30
# 1        om   33   chemical  2023-12-23
# 2     shubz   44         IT   2024-12-2

# %%
data2.to_csv('data2.csv', index=False)

# %%
load = pd.read_csv('data2.csv')

# %%
load
# Out:
#   Full_name  age department  joing_Date
# 0    vishal   22   computer  2002-01-30
# 1        om   33   chemical  2023-12-23
# 2     shubz   44         IT   2024-12-2

# %%
data2
# Out:
#   Full_name  age department  joing_Date
# 0    vishal   22   computer  2002-01-30
# 1        om   33   chemical  2023-12-23
# 2     shubz   44         IT   2024-12-2

# %%
data2[['age', 'department']]
# Out:
#    age department
# 0   22   computer
# 1   33   chemical
# 2   44         IT

# %%
data2.loc[data2.Full_name == 'vishal']
# Out:
#   Full_name  age department  joing_Date
# 0    vishal   22   computer  2002-01-30

# %%
data2['joing_Date'].dtype
# Out:
# dtype('O')

# %%
data2['joing_Date'] = pd.to_datetime(data2['joing_Date'], format='%y-%m-%d')

# %%
data2['joing_Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
data2['joing_Date'].dt.year
# Out:
# 0    2002
# 1    2023
# 2    2024
# Name: joing_Date, dtype: int32

# %%
data2.isnull()
# Out:
#    Full_name    age  department  joing_Date
# 0      False  False       False       False
# 1      False  False       False       False
# 2      False  False       False       False

# %%
data2.isnull().sum()
# Out:
# Full_name     0
# age           0
# department    0
# joing_Date    0
# dtype: int64

# %%
data2.fillna(0)
# Out:
#   Full_name  age department joing_Date
# 0    vishal   22   computer 2002-01-30
# 1        om   33   chemical 2023-12-23
# 2     shubz   44         IT 2024-12-02

# %%
data2
# Out:
#   Full_name  age department joing_Date
# 0    vishal   22   computer 2002-01-30
# 1        om   33   chemical 2023-12-23
# 2     shubz   44         IT 2024-12-02

# %%
data2['salary'] = [1111,111,111]

# %%
data2
# Out:
#   Full_name  age department joing_Date  salary
# 0    vishal   22   computer 2002-01-30    1111
# 1        om   33   chemical 2023-12-23     111
# 2     shubz   44         IT 2024-12-02     111

# %%
data2.drop('salary', axis=1)
# Out:
#   Full_name  age department joing_Date
# 0    vishal   22   computer 2002-01-30
# 1        om   33   chemical 2023-12-23
# 2     shubz   44         IT 2024-12-02
