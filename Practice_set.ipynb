# %%
import pandas as pd;

# %%
df = pd.DataFrame([1,2,3], columns=['number'])
df
# Out:
#    number
# 0       1
# 1       2
# 2       3

# %%
data = pd.DataFrame(['vishal', 'om'], columns=['name'])
data}
# Out:
#      name
# 0  vishal
# 1      om

# %%
data1 = pd.DataFrame({
    'name':['vishal', 'om', 'Shubz'], 
    'age':[11,22,33]
})
data1
# Out:
#      name  age
# 0  vishal   11
# 1      om   22
# 2   Shubz   33

# %%
data1.head(1)
# Out:
#      name  age
# 0  vishal   11

# %%
data1.tail(1)
# Out:
#     name  age
# 2  Shubz   33

# %%
data1.shape
# Out:
# (3, 2)

# %%
data1.size
# Out:
# 6

# %%
data1.info
# Out:
# <bound method DataFrame.info of      name  age
# 0  vishal   11
# 1      om   22
# 2   Shubz   33>

# %%
data1.describe()
# Out:
#         age
# count   3.0
# mean   22.0
# std    11.0
# min    11.0
# 25%    16.5
# 50%    22.0
# 75%    27.5
# max    33.0

# %%
df = data1.rename(columns={'name':'full_name'})
df
# Out:
#   full_name  age
# 0    vishal   11
# 1        om   22
# 2     Shubz   33

# %%
data1.describe()
# Out:
#         age
# count   3.0
# mean   22.0
# std    11.0
# min    11.0
# 25%    16.5
# 50%    22.0
# 75%    27.5
# max    33.0

# %%
data1.info
# Out:
# <bound method DataFrame.info of      name  age
# 0  vishal   11
# 1      om   22
# 2   Shubz   33>

# %%
data1.to_csv('basic_data', index=False)

# %%
load = pd.read_csv('basic_data')

# %%
load
# Out:
#      name  age
# 0  vishal   11
# 1      om   22
# 2   Shubz   33

# %%
data = pd.DataFrame(load)
data
# Out:
#      name
# 0  vishal
# 1      om
# 2   Shubz

# %%
data[['name']]
# Out:
#      name
# 0  vishal
# 1      om
# 2   Shubz

# %%
data['age'] = [22, 33, 44]

# %%
data
# Out:
#      name  age
# 0  vishal   22
# 1      om   33
# 2   Shubz   44

# %%
data[['name', 'age']]
# Out:
#      name  age
# 0  vishal   22
# 1      om   33
# 2   Shubz   44

# %%
data.loc[data.name == 'vishal']
# Out:
#      name  age
# 0  vishal   22

# %%
data.loc[ : 2]
# Out:
#      name  age
# 0  vishal   22
# 1      om   33
# 2   Shubz   44

# %%
data.iloc[ : 2]
# Out:
#      name  age
# 0  vishal   22
# 1      om   33
