# %%
! pip install pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
# 1. Data Frame.............................................

# %%
arr1 = pd.DataFrame([1,2,3], columns=['Col_num'])
arr1
# Out:
#    Col_num
# 0        1
# 1        2
# 2        3

# %%
data = {
  'name': ['Vishal', 'om', 'Shubz'],
   'age':[11,11,11]
}

data = pd.DataFrame(data)
data
# Out:
#      name  age
# 0  Vishal   11
# 1      om   11
# 2   Shubz   11

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
 # basic data frame Undestand

# %%
data.head(2)
# Out:
#      name  age
# 0  Vishal   11
# 1      om   11

# %%
data.tail(2)
# Out:
#     name  age
# 1     om   11
# 2  Shubz   11

# %%
data.shape
# Out:
# (3, 2)

# %%
data.columns
# Out:
# Index(['name', 'age'], dtype='object')

# %%
data = data.rename(columns={'name':'full_name'})
data
# Out:
#   full_name  age
# 0    Vishal   11
# 1        om   11
# 2     Shubz   11

# %%
data
# Out:
#   full_name  age
# 0    Vishal   11
# 1        om   11
# 2     Shubz   11

# %%
data.info
# Out:
# <bound method DataFrame.info of   full_name  age
# 0    Vishal   11
# 1        om   11
# 2     Shubz   11>

# %%
data.describe()
# Out:
#         age
# count   3.0
# mean   11.0
# std     0.0
# min    11.0
# 25%    11.0
# 50%    11.0
# 75%    11.0
# max    11.0

# %%
# 3. save and Load data from csv:

# %%
data
# Out:
#   full_name  age
# 0    Vishal   11
# 1        om   11
# 2     Shubz   11

# %%
data.to_csv('Test_data.csv', index=False)

# %%
load = pd.read_csv('Test_data.csv')
load
# Out:
#   full_name  age
# 0    Vishal   11
# 1        om   33
# 2     Shubz   55
