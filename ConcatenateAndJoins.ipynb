# %%
import pandas as pd;

# %%
df1 = pd.DataFrame({'ID':[1,2,3], 'Score':[33,55,66]})
df1
# Out:
#    ID  Score
# 0   1     33
# 1   2     55
# 2   3     66

# %%
df2 = pd.DataFrame({'ID':[1,2,3,4], 'Score':[22,44,55,66]})
df2
# Out:
#    ID  Score
# 0   1     22
# 1   2     44
# 2   3     55
# 3   4     66

# %%
pd.concat([df1, df2], axis=0)
# Out:
#    ID  Score
# 0   1     33
# 1   2     55
# 2   3     66
# 0   1     22
# 1   2     44
# 2   3     55
# 3   4     66

# %%
pd.concat([df1,df2], axis=1)
# Out:
#     ID  Score  ID  Score
# 0  1.0   33.0   1     22
# 1  2.0   55.0   2     44
# 2  3.0   66.0   3     55
# 3  NaN    NaN   4     66

# %%
# Joins...........................

# %%
pd.merge(df1,df2, how='inner', on='ID')
# Out:
#    ID  Score_x  Score_y
# 0   1       33       22
# 1   2       55       44
# 2   3       66       55
